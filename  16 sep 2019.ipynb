# %% [markdown]
# ![k6.jpg](attachment:k6.jpg)# Date : 16th sep 2019
# ## Problem solving with python
# ### Markdown
# #### Day Objectives:
# * Literate programming: it is a combination of both programming and documentation.
# * Jupyter Notebook Environment
# * Markdown format for documentation
#
# **keerthana sri**
#
#
# ***keerthana sri***

# %% [markdown]
# **Operators**

# %%
num = 2 + 4

# %%
num1=9
num2=7
num1
# Out:
# 9

# %%
""" multiple line
comments
"""
print('welcome to python') # single line comment
# Out:
# welcome to python

# %%
print(welcome)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-fab115d2dd65> in <module>
# ----> 1 print(welcome)
#
# NameError: name 'welcome' is not defined

# %%
a++
# Out:
#   File "<ipython-input-9-22e3d6dc1353>", line 1
#     a++
#        ^
# SyntaxError: invalid syntax

# %%
a += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8076006b0952> in <module>
# ----> 1 a += 1
#
# NameError: name 'a' is not defined

# %%
a =90
a += 1
a
# Out:
# 91

# %%
a=8
a*=3
a
# Out:
# 24

# %%
b=9
b-=8
b
# Out:
# 1

# %% [markdown]
# ## assignment operators
# '='
# '+='
# '-='
# '/='
# '*='

# %% [markdown]
# ## Relational operators
# '<='
# '>='
# '=='
# '!='

# %%
_ is used to store previous values
# Out:
# 1

# %%
_=12
_
# Out:
# 12

# %%
23!=2
# Out:
# True

# %%
2>=78
# Out:
# False

# %%
s=2>=78

# %%
type(s)
# Out:
# bool
